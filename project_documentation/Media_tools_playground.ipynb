# %% [markdown]
# # Media tools playground

# %%
from media_tools import *
sample_media = "C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/"

# %%
vid_save_path = sample_media+"sample_video.mp4"

# testing video pipeline with video image array [V]
clip, fps = video_tools.read_video(vid_save_path, video_as_array=True)
image_tools.show_image(clip[1], BGR=True)
video_tools.save_video(clip, vid_save_path, fps)
# Out:
# Moviepy - Building video C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4.
# Moviepy - Writing video C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4
# Moviepy - Done !
# Moviepy - video ready C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4

# %%
# testing video pipeline with video object [V]
clip = video_tools.read_video(vid_save_path, video_as_array=False)
image_tools.show_image(clip.get_frame(1), BGR=True)
video_tools.save_video(clip, vid_save_path, video_is_image_array=False)
# Out:
# Moviepy - Building video C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4.
# Moviepy - Writing video C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4
# Moviepy - Done !
# Moviepy - video ready C:/Users/pdazeley-gaist23/PycharmProjects/Image_and_Audio_Generation_and_Editing_using_Python/sample_media/sample_video.mp4

# %%
# getting audio from a video file
video_tools.save_audio_from_video(str(sample_media+"sample_video.mp4"), str(sample_media+"example_audio_from_video.wav"))
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\PDAZEL~1\AppData\Local\Temp/ipykernel_13656/431072159.py in <module>
#       1 # getting audio from a video file
# ----> 2 video_tools.save_audio_from_video(str(sample_media+"sample_video.mp4"), str(sample_media+"example_audio_from_video.wav"))
#       3
#
# ~\PycharmProjects\Image_and_Audio_Generation_and_Editing_using_Python\media_tools\video_tools.py in save_audio_from_video(video_path, audio_save_path)
#      77     clip.audio.write_audiofile(audio_save_path)
#      78
# ---> 79
#      80 """
#      81 assign audio to a video file
#
# AttributeError: 'NoneType' object has no attribute 'write_audiofile'

# %%
# assigning audio to a video file [V]
audio_stereo, sr = audio_tools.read_audio(str(sample_media+"stereo_sample.wav"), mono=False)
audio_mono, sr = audio_tools.read_audio(str(sample_media+"stereo_sample.wav"), mono=False)
video = video_tools.read_video(str(sample_media+"sample_video.mp4"), video_as_array=False)
video_array, fps = video_tools.read_video(str(sample_media+"sample_video.mp4"), video_as_array=True)

vid_save_path_1 = sample_media+"sample_video.mp4"
vid_save_path_2 = sample_media+"sample_video.mp4"

video = video_tools.assign_audio_to_video(audio_mono, video, video_is_image_array=False)
video_array = video_tools.assign_audio_to_video(audio_mono, video_array, video_is_image_array=True)

video_tools.save_video(video=video, path=vid_save_path_1, video_is_image_array=False)
video_tools.save_video(video=video_array, path=vid_save_path_2, video_is_image_array=False)
